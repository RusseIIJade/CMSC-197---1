# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv("movie_metadata_cleaned.csv")

# %%
data.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    num_user_for_reviews language country  content_rating       budget  \
# 0                3054.0  English     USA           PG-13  237000000.0
# 1                1238.0  English     USA           PG-13  300000000.0
#
#   title_year  actor_2_facebook_likes imdb_score aspect_ratio  \
# 0     2009.0                   936.0        7.9         1.78
# 1     2007.0                  5000.0        7.1         2.35
#
#    movie_facebook_likes
# 0               33000.0
# 1                   0.0
#
# [2 rows x 29 columns]

# %% [markdown]
# ## Get the top 10 directors with most movies directed and use a boxplot for their gross earnings

# %%
#Get the top 10 names of the directors based on the number of their directed movies.
top10_directors_with_most_movies = (data.groupby(data.director_name).nunique().movie_title.nlargest(10))
plot_top10_directors = data[data["director_name"].isin(top10_directors_with_most_movies.index)]

#Size of plot.
plt.figure(figsize=(20,5))
sns.boxplot(x="director_name", y="gross", data = plot_top10_directors)
plt.show()

# %% [markdown]
# ## Plot the following variables in one graph:
#
# - num_critic_for_reviews
# - IMDB score
# - gross

# %%
#Setting up the box plot with thier labels.
plt.boxplot([data['num_critic_for_reviews'], data['imdb_score'], data['gross']], labels = ['num_critic_for_reviews' , 'IMDB score', 'gross'])
plt.show()

# %% [markdown]
# ## Compute Sales (Gross - Budget), add it as another column

# %%
#The difference of gross and budget will be added to a new column "sales".
data['sales'] = data['gross'] - data['budget']
data.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    language country content_rating       budget  title_year  \
# 0   English     USA          PG-13  237000000.0      2009.0
# 1   English     USA          PG-13  300000000.0      2007.0
#
#   actor_2_facebook_likes  imdb_score aspect_ratio movie_facebook_likes  \
# 0                  936.0         7.9         1.78              33000.0
# 1                 5000.0         7.1         2.35                  0.0
#
#          sales
# 0  523505847.0
# 1    9404152.0
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Which directors garnered the most total sales?

# %%
#Top 10 Directors with most sales.
#Fun fact: Asian directors have the lowest sales if we set ascending=True.
directors_with_most_total_sales = data.groupby("director_name")["sales"].sum().sort_values(ascending=False)[:10].to_frame()
directors_with_most_total_sales
# Out:
#                           sales
# director_name
# Steven Spielberg   2.451332e+09
# George Lucas       1.386641e+09
# James Cameron      1.199626e+09
# Joss Whedon        1.000887e+09
# Chris Columbus     9.417076e+08
# Peter Jackson      9.009693e+08
# Tim Burton         8.242755e+08
# Christopher Nolan  8.082276e+08
# Jon Favreau        7.693815e+08
# Francis Lawrence   7.555020e+08

# %% [markdown]
# ## Plot sales and average likes as a scatterplot. Fit it with a line.

# %%
#movie_facebook_likes is the average likes.
sns.lmplot(x="sales", y="movie_facebook_likes", data=data, height=5)
plt.show()

# %% [markdown]
# ## Which of these genres are the most profitable? Plot their sales using different histograms, superimposed in the same axis.
#
# - Romance
# - Comedy
# - Action
# - Fantasy

# %%
#Generating histograms and assigning different colors each.
ax = sns.histplot(data[data['genres'] == 'Romance']["sales"], color="red", label="Romance", kde=True, stat="density", linewidth=0)
sns.histplot(data[data['genres'] == 'Comedy']["sales"], color="teal", label="Comedy", kde=True, stat="density", linewidth=0, ax=ax)
sns.histplot(data[data['genres'] == 'Action']["sales"], color="blue", label="Action", kde=True, stat="density", linewidth=0, ax=ax)
sns.histplot(data[data['genres'] == 'Fantasy']["sales"], color="yellow", label="Fantasy", kde=True, stat="density", linewidth=0, ax=ax)
ax.legend()
plt.show()

# %% [markdown]
# ## For each of movie, compute average likes of the three actors and store it as a new variable
#
# Read up on the mean function.
#
# Store it as a new column, average_actor_likes.

# %%
#Computing the average likes of the 3 actors and storing them to average_actor_likes.
data['average_actor_likes'] = data[['actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']].mean(axis=1)
data.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    country content_rating       budget  title_year  actor_2_facebook_likes  \
# 0      USA          PG-13  237000000.0      2009.0                   936.0
# 1      USA          PG-13  300000000.0      2007.0                  5000.0
#
#   imdb_score  aspect_ratio movie_facebook_likes        sales  \
# 0        7.9          1.78              33000.0  523505847.0
# 1        7.1          2.35                  0.0    9404152.0
#
#    average_actor_likes
# 0           930.333333
# 1         15333.333333
#
# [2 rows x 31 columns]

# %% [markdown]
# ## Copying the whole dataframe

# %%
df = data.copy()
df.head()
# Out:
#    Unnamed: 0                                        movie_title  color  \
# 0           0                                          b'Avatar'  Color
# 1           1        b"Pirates of the Caribbean: At World's End"  Color
# 2           2                                         b'Spectre'  Color
# 3           3                           b'The Dark Knight Rises'  Color
# 4           4  b'Star Wars: Episode VII - The Force Awakens  ...      0
#
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 4        Doug Walker                     0.0       0.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     0.0        Rob Walker
#
#    actor_1_facebook_likes  ...  country content_rating       budget  \
# 0                  1000.0  ...      USA          PG-13  237000000.0
# 1                 40000.0  ...      USA          PG-13  300000000.0
# 2                 11000.0  ...       UK          PG-13  245000000.0
# 3                 27000.0  ...      USA          PG-13  250000000.0
# 4                   131.0  ...        0              0          0.0
#
#    title_year  actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                   936.0        7.9          1.78
# 1      2007.0                  5000.0        7.1          2.35
# 2      2015.0                   393.0        6.8          2.35
# 3      2012.0                 23000.0        8.5          2.35
# 4         0.0                    12.0        7.1          0.00
#
#   movie_facebook_likes        sales  average_actor_likes
# 0              33000.0  523505847.0           930.333333
# 1                  0.0    9404152.0         15333.333333
# 2              85000.0  -44925825.0          3851.333333
# 3             164000.0  198130642.0         24333.333333
# 4                  0.0          0.0            47.666667
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Min-Max Normalization
#
# Normalization is a technique often applied as part of data preparation for machine learning. The goal of normalization is to change the values of numeric columns in the dataset to a common scale, without distorting differences in the ranges of values. For machine learning, every dataset does not require normalization. It is required only when features have different ranges.
#
# The min-max approach (often called normalization) rescales the feature to a hard and fast range of [0,1] by subtracting the minimum value of the feature then dividing by the range. We can apply the min-max scaling in Pandas using the .min() and .max() methods.
#
# $$
# x_{scaled} = \frac{x-x_{min}}{x_{max}-x_{min}}
# $$

# %% [markdown]
# ### Normalize each numeric column (those that have types integer or float) of the copied dataframe (df)

# %%
#Normalization of num_critic_for_reviews
max = df['num_critic_for_reviews'].max()
min = df['num_critic_for_reviews'].min()
df['nm_num_critic_for_reviews'] = (data['num_critic_for_reviews'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    content_rating       budget title_year  actor_2_facebook_likes  imdb_score  \
# 0           PG-13  237000000.0     2009.0                   936.0         7.9
# 1           PG-13  300000000.0     2007.0                  5000.0         7.1
#
#   aspect_ratio  movie_facebook_likes        sales average_actor_likes  \
# 0         1.78               33000.0  523505847.0          930.333333
# 1         2.35                   0.0    9404152.0        15333.333333
#
#    nm_num_critic_for_reviews
# 0                   0.889299
# 1                   0.371464
#
# [2 rows x 32 columns]

# %%
#Normalization of duration
max = df['duration'].max()
min = df['duration'].min()
df['nm_duration'] = (data['duration'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#         budget title_year actor_2_facebook_likes  imdb_score  aspect_ratio  \
# 0  237000000.0     2009.0                  936.0         7.9          1.78
# 1  300000000.0     2007.0                 5000.0         7.1          2.35
#
#   movie_facebook_likes        sales average_actor_likes  \
# 0              33000.0  523505847.0          930.333333
# 1                  0.0    9404152.0        15333.333333
#
#   nm_num_critic_for_reviews  nm_duration
# 0                  0.889299     0.941799
# 1                  0.371464     0.894180
#
# [2 rows x 33 columns]

# %%
#Normalization of director_facebook_likes
max = df['director_facebook_likes'].max()
min = df['director_facebook_likes'].min()
df['nm_director_facebook_likes'] = (data['director_facebook_likes'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
#
#    movie_facebook_likes        sales  average_actor_likes  \
# 0               33000.0  523505847.0           930.333333
# 1                   0.0    9404152.0         15333.333333
#
#   nm_num_critic_for_reviews nm_duration  nm_director_facebook_likes
# 0                  0.889299    0.941799                    0.000000
# 1                  0.371464    0.894180                    0.024478
#
# [2 rows x 34 columns]

# %%
#Normalization of actor_3_facebook_likes
max = df['actor_3_facebook_likes'].max()
min = df['actor_3_facebook_likes'].min()
df['nm_actor_3_facebook_likes'] = (data['actor_3_facebook_likes'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                   936.0        7.9         1.78               33000.0
# 1                  5000.0        7.1         2.35                   0.0
#
#          sales average_actor_likes  nm_num_critic_for_reviews nm_duration  \
# 0  523505847.0          930.333333                   0.889299    0.941799
# 1    9404152.0        15333.333333                   0.371464    0.894180
#
#   nm_director_facebook_likes  nm_actor_3_facebook_likes
# 0                   0.000000                   0.037174
# 1                   0.024478                   0.043478
#
# [2 rows x 35 columns]

# %%
#Normalization of actor_1_facebook_likes
max = df['actor_1_facebook_likes'].max()
min = df['actor_1_facebook_likes'].min()
df['nm_actor_1_facebook_likes'] = (data['actor_1_facebook_likes'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    imdb_score aspect_ratio movie_facebook_likes        sales  \
# 0         7.9         1.78              33000.0  523505847.0
# 1         7.1         2.35                  0.0    9404152.0
#
#    average_actor_likes nm_num_critic_for_reviews  nm_duration  \
# 0           930.333333                  0.889299     0.941799
# 1         15333.333333                  0.371464     0.894180
#
#   nm_director_facebook_likes nm_actor_3_facebook_likes  \
# 0                   0.000000                  0.037174
# 1                   0.024478                  0.043478
#
#    nm_actor_1_facebook_likes
# 0                   0.001563
# 1                   0.062500
#
# [2 rows x 36 columns]

# %%
#Normalization of gross
max = df['gross'].max()
min = df['gross'].min()
df['nm_gross'] = (data['gross'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    aspect_ratio movie_facebook_likes        sales  average_actor_likes  \
# 0          1.78              33000.0  523505847.0           930.333333
# 1          2.35                  0.0    9404152.0         15333.333333
#
#    nm_num_critic_for_reviews nm_duration  nm_director_facebook_likes  \
# 0                   0.889299    0.941799                    0.000000
# 1                   0.371464    0.894180                    0.024478
#
#   nm_actor_3_facebook_likes nm_actor_1_facebook_likes  nm_gross
# 0                  0.037174                  0.001563   1.00000
# 1                  0.043478                  0.062500   0.40684
#
# [2 rows x 37 columns]

# %%
#Normalization of num_voted_users
max = df['num_voted_users'].max()
min = df['num_voted_users'].min()
df['nm_num_voted_users'] = (data['num_voted_users'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    movie_facebook_likes        sales average_actor_likes  \
# 0               33000.0  523505847.0          930.333333
# 1                   0.0    9404152.0        15333.333333
#
#    nm_num_critic_for_reviews  nm_duration nm_director_facebook_likes  \
# 0                   0.889299     0.941799                   0.000000
# 1                   0.371464     0.894180                   0.024478
#
#    nm_actor_3_facebook_likes nm_actor_1_facebook_likes nm_gross  \
# 0                   0.037174                  0.001563  1.00000
# 1                   0.043478                  0.062500  0.40684
#
#    nm_num_voted_users
# 0            0.524454
# 1            0.278867
#
# [2 rows x 38 columns]

# %%
#Normalization of cast_total_facebook_likes
max = df['cast_total_facebook_likes'].max()
min = df['cast_total_facebook_likes'].min()
df['nm_cast_total_facebook_likes'] = (data['cast_total_facebook_likes'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#          sales average_actor_likes nm_num_critic_for_reviews  nm_duration  \
# 0  523505847.0          930.333333                  0.889299     0.941799
# 1    9404152.0        15333.333333                  0.371464     0.894180
#
#    nm_director_facebook_likes nm_actor_3_facebook_likes  \
# 0                    0.000000                  0.037174
# 1                    0.024478                  0.043478
#
#    nm_actor_1_facebook_likes nm_gross nm_num_voted_users  \
# 0                   0.001563  1.00000           0.524454
# 1                   0.062500  0.40684           0.278867
#
#    nm_cast_total_facebook_likes
# 0                      0.007361
# 1                      0.073622
#
# [2 rows x 39 columns]

# %%
#Normalization of facenumber_in_poster
max = df['facenumber_in_poster'].max()
min = df['facenumber_in_poster'].min()
df['nm_facenumber_in_poster'] = (data['facenumber_in_poster'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    average_actor_likes nm_num_critic_for_reviews nm_duration  \
# 0           930.333333                  0.889299    0.941799
# 1         15333.333333                  0.371464    0.894180
#
#    nm_director_facebook_likes  nm_actor_3_facebook_likes  \
# 0                    0.000000                   0.037174
# 1                    0.024478                   0.043478
#
#   nm_actor_1_facebook_likes  nm_gross nm_num_voted_users  \
# 0                  0.001563   1.00000           0.524454
# 1                  0.062500   0.40684           0.278867
#
#   nm_cast_total_facebook_likes  nm_facenumber_in_poster
# 0                     0.007361                      0.0
# 1                     0.073622                      0.0
#
# [2 rows x 40 columns]

# %%
#Normalization of num_user_for_reviews
max = df['num_user_for_reviews'].max()
min = df['num_user_for_reviews'].min()
df['nm_num_user_for_reviews'] = (data['num_user_for_reviews'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    nm_num_critic_for_reviews nm_duration nm_director_facebook_likes  \
# 0                   0.889299    0.941799                   0.000000
# 1                   0.371464    0.894180                   0.024478
#
#    nm_actor_3_facebook_likes  nm_actor_1_facebook_likes nm_gross  \
# 0                   0.037174                   0.001563  1.00000
# 1                   0.043478                   0.062500  0.40684
#
#    nm_num_voted_users nm_cast_total_facebook_likes nm_facenumber_in_poster  \
# 0            0.524454                     0.007361                     0.0
# 1            0.278867                     0.073622                     0.0
#
#    nm_num_user_for_reviews
# 0                 0.603557
# 1                 0.244664
#
# [2 rows x 41 columns]

# %%
#Normalization of budget
max = df['budget'].max()
min = df['budget'].min()
df['nm_budget'] = (data['budget'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    nm_duration nm_director_facebook_likes nm_actor_3_facebook_likes  \
# 0     0.941799                   0.000000                  0.037174
# 1     0.894180                   0.024478                  0.043478
#
#    nm_actor_1_facebook_likes  nm_gross nm_num_voted_users  \
# 0                   0.001563   1.00000           0.524454
# 1                   0.062500   0.40684           0.278867
#
#    nm_cast_total_facebook_likes nm_facenumber_in_poster  \
# 0                      0.007361                     0.0
# 1                      0.073622                     0.0
#
#   nm_num_user_for_reviews  nm_budget
# 0                0.603557   0.019402
# 1                0.244664   0.024559
#
# [2 rows x 42 columns]

# %%
#Normalization of title_year
max = df['title_year'].max()
min = df['title_year'].min()
df['nm_title_year'] = (data['title_year'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    nm_director_facebook_likes nm_actor_3_facebook_likes  \
# 0                    0.000000                  0.037174
# 1                    0.024478                  0.043478
#
#   nm_actor_1_facebook_likes  nm_gross  nm_num_voted_users  \
# 0                  0.001563   1.00000            0.524454
# 1                  0.062500   0.40684            0.278867
#
#   nm_cast_total_facebook_likes  nm_facenumber_in_poster  \
# 0                     0.007361                      0.0
# 1                     0.073622                      0.0
#
#   nm_num_user_for_reviews nm_budget  nm_title_year
# 0                0.603557  0.019402       0.996528
# 1                0.244664  0.024559       0.995536
#
# [2 rows x 43 columns]

# %%
#Normalization of actor_2_facebook_likes
max = df['actor_2_facebook_likes'].max()
min = df['actor_2_facebook_likes'].min()
df['nm_actor_2_facebook_likes'] = (data['actor_2_facebook_likes'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    nm_actor_3_facebook_likes nm_actor_1_facebook_likes nm_gross  \
# 0                   0.037174                  0.001563  1.00000
# 1                   0.043478                  0.062500  0.40684
#
#    nm_num_voted_users  nm_cast_total_facebook_likes nm_facenumber_in_poster  \
# 0            0.524454                      0.007361                     0.0
# 1            0.278867                      0.073622                     0.0
#
#    nm_num_user_for_reviews nm_budget nm_title_year  nm_actor_2_facebook_likes
# 0                 0.603557  0.019402      0.996528                   0.006832
# 1                 0.244664  0.024559      0.995536                   0.036496
#
# [2 rows x 44 columns]

# %%
#Normalization of imdb_score
max = df['imdb_score'].max()
min = df['imdb_score'].min()
df['nm_imdb_score'] = (data['imdb_score'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    nm_actor_1_facebook_likes nm_gross nm_num_voted_users  \
# 0                   0.001563  1.00000           0.524454
# 1                   0.062500  0.40684           0.278867
#
#    nm_cast_total_facebook_likes  nm_facenumber_in_poster  \
# 0                      0.007361                      0.0
# 1                      0.073622                      0.0
#
#   nm_num_user_for_reviews  nm_budget nm_title_year nm_actor_2_facebook_likes  \
# 0                0.603557   0.019402      0.996528                  0.006832
# 1                0.244664   0.024559      0.995536                  0.036496
#
#    nm_imdb_score
# 0       0.831579
# 1       0.747368
#
# [2 rows x 45 columns]

# %%
#Normalization of aspect_ratio
max = df['aspect_ratio'].max()
min = df['aspect_ratio'].min()
df['nm_aspect_ratio'] = (data['aspect_ratio'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    nm_gross nm_num_voted_users nm_cast_total_facebook_likes  \
# 0   1.00000           0.524454                     0.007361
# 1   0.40684           0.278867                     0.073622
#
#    nm_facenumber_in_poster  nm_num_user_for_reviews nm_budget  nm_title_year  \
# 0                      0.0                 0.603557  0.019402       0.996528
# 1                      0.0                 0.244664  0.024559       0.995536
#
#   nm_actor_2_facebook_likes nm_imdb_score  nm_aspect_ratio
# 0                  0.006832      0.831579         0.111250
# 1                  0.036496      0.747368         0.146875
#
# [2 rows x 46 columns]

# %%
#Normalization of movie_facebook_likes
max = df['movie_facebook_likes'].max()
min = df['movie_facebook_likes'].min()
df['nm_movie_facebook_likes'] = (data['movie_facebook_likes'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    nm_num_voted_users nm_cast_total_facebook_likes nm_facenumber_in_poster  \
# 0            0.524454                     0.007361                     0.0
# 1            0.278867                     0.073622                     0.0
#
#    nm_num_user_for_reviews  nm_budget nm_title_year  \
# 0                 0.603557   0.019402      0.996528
# 1                 0.244664   0.024559      0.995536
#
#    nm_actor_2_facebook_likes nm_imdb_score nm_aspect_ratio  \
# 0                   0.006832      0.831579        0.111250
# 1                   0.036496      0.747368        0.146875
#
#    nm_movie_facebook_likes
# 0                 0.094556
# 1                 0.000000
#
# [2 rows x 47 columns]

# %%
#Normalization of sales
max = df['sales'].max()
min = df['sales'].min()
df['nm_sales'] = (data['sales'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    nm_cast_total_facebook_likes nm_facenumber_in_poster  \
# 0                      0.007361                     0.0
# 1                      0.073622                     0.0
#
#   nm_num_user_for_reviews  nm_budget  nm_title_year nm_actor_2_facebook_likes  \
# 0                0.603557   0.019402       0.996528                  0.006832
# 1                0.244664   0.024559       0.995536                  0.036496
#
#    nm_imdb_score nm_aspect_ratio nm_movie_facebook_likes  nm_sales
# 0       0.831579        0.111250                0.094556  1.000000
# 1       0.747368        0.146875                0.000000  0.959637
#
# [2 rows x 48 columns]

# %%
#Normalization of average_actor_likes
max = df['average_actor_likes'].max()
min = df['average_actor_likes'].min()
df['nm_average_actor_likes'] = (data['average_actor_likes'] - min) / (max-min)
df.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    nm_facenumber_in_poster nm_num_user_for_reviews nm_budget  nm_title_year  \
# 0                      0.0                0.603557  0.019402       0.996528
# 1                      0.0                0.244664  0.024559       0.995536
#
#    nm_actor_2_facebook_likes nm_imdb_score  nm_aspect_ratio  \
# 0                   0.006832      0.831579         0.111250
# 1                   0.036496      0.747368         0.146875
#
#   nm_movie_facebook_likes  nm_sales  nm_average_actor_likes
# 0                0.094556  1.000000                0.004261
# 1                0.000000  0.959637                0.070229
#
# [2 rows x 49 columns]
